# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /home/pranit/.local/lib/python3.9/site-packages (2.0.1)

# %%
# !pip install scikit_posthocs
# Out:
# Requirement already satisfied: scikit_posthocs in /home/pranit/.local/lib/python3.9/site-packages (0.9.0)
# Requirement already satisfied: statsmodels in /home/pranit/.local/lib/python3.9/site-packages (from scikit_posthocs) (0.14.1)
# Requirement already satisfied: pandas>=0.20.0 in /home/pranit/.local/lib/python3.9/site-packages (from scikit_posthocs) (2.0.3)
# Requirement already satisfied: seaborn in /home/pranit/.local/lib/python3.9/site-packages (from scikit_posthocs) (0.12.2)
# Requirement already satisfied: scipy>=1.9.0 in /home/pranit/.local/lib/python3.9/site-packages (from scikit_posthocs) (1.10.1)
# Requirement already satisfied: matplotlib in /home/pranit/.local/lib/python3.9/site-packages (from scikit_posthocs) (3.5.2)
# Requirement already satisfied: numpy in /home/pranit/.local/lib/python3.9/site-packages (from scikit_posthocs) (1.21.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.20.0->scikit_posthocs) (2021.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pranit/.local/lib/python3.9/site-packages (from pandas>=0.20.0->scikit_posthocs) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/pranit/.local/lib/python3.9/site-packages (from pandas>=0.20.0->scikit_posthocs) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->scikit_posthocs) (1.16.0)
# Requirement already satisfied: cycler>=0.10 in /home/pranit/.local/lib/python3.9/site-packages (from matplotlib->scikit_posthocs) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/pranit/.local/lib/python3.9/site-packages (from matplotlib->scikit_posthocs) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/pranit/.local/lib/python3.9/site-packages (from matplotlib->scikit_posthocs) (10.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/pranit/.local/lib/python3.9/site-packages (from matplotlib->scikit_posthocs) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pranit/.local/lib/python3.9/site-packages (from matplotlib->scikit_posthocs) (4.33.3)
# Requirement already satisfied: packaging>=20.0 in /home/pranit/.local/lib/python3.9/site-packages (from matplotlib->scikit_posthocs) (24.0)
# Requirement already satisfied: patsy>=0.5.4 in /home/pranit/.local/lib/python3.9/site-packages (from statsmodels->scikit_posthocs) (0.5.6)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from scipy.stats import kstest
from scipy.stats import spearmanr
import numpy as np
from scipy.stats import ttest_ind
from scipy.stats import kstest, levene
from scipy.stats import kruskal
import scikit_posthocs as sp
from scipy.stats import mannwhitneyu
from scipy.stats import ttest_rel
from scipy.stats import wilcoxon
import random

# %% [markdown]
# Part 1 of EDA

# %%
excel_file_path = 'DataForTable2.1WHR2023.xls'

df = pd.read_excel(excel_file_path)

print(df)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018     3.616480            7.783066        0.775388
# 2195     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2196     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2197     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2198     Zimbabwe  2022     3.296220            7.670123        0.666172
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            50.500000                      0.718114
# 1                            50.799999                      0.678896
# 2                            51.099998                      0.600127
# 3                            51.400002                      0.495901
# 4                            51.700001                      0.530935
# ...                                ...                           ...
# 2194                         52.625000                      0.762675
# 2195                         53.099998                      0.631908
# 2196                         53.575001                      0.643303
# 2197                         54.049999                      0.667636
# 2198                         54.525002                      0.651987
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 0       0.167652                   0.881686         0.414297         0.258195
# 1       0.190809                   0.850035         0.481421         0.237092
# 2       0.121316                   0.706766         0.516907         0.275324
# 3       0.163571                   0.731109         0.479835         0.267175
# 4       0.237588                   0.775620         0.613513         0.267919
# ...          ...                        ...              ...              ...
# 2194   -0.051219                   0.844209         0.657524         0.211726
# 2195   -0.047464                   0.830652         0.658434         0.235354
# 2196    0.006313                   0.788523         0.660658         0.345736
# 2197   -0.075575                   0.756945         0.609917         0.241682
# 2198   -0.069513                   0.752632         0.640609         0.191350
#
# [2199 rows x 11 columns]

# %%
#a.	Which country has the highest score? Why? 
grouped = df.groupby('year')
max_indices = grouped['Life Ladder'].idxmax()
max_life_ladder_countries = df.loc[max_indices]

print("Country with highest Life Ladder score for each year:")
print(max_life_ladder_countries[['year', 'Country name', 'Life Ladder']])
# Out:
# Country with highest Life Ladder score for each year:
#       year Country name  Life Ladder
# 505   2005      Denmark     8.018934
# 623   2006      Finland     7.672449
# 506   2007      Denmark     7.834233
# 507   2008      Denmark     7.970892
# 508   2009      Denmark     7.683359
# 509   2010      Denmark     7.770515
# 510   2011      Denmark     7.788232
# 1868  2012  Switzerland     7.776209
# 334   2013       Canada     7.593794
# 513   2014      Denmark     7.507559
# 1477  2015       Norway     7.603434
# 631   2016      Finland     7.659843
# 632   2017      Finland     7.788252
# 633   2018      Finland     7.858107
# 634   2019      Finland     7.780348
# 635   2020      Finland     7.889350
# 636   2021      Finland     7.794378
# 637   2022      Finland     7.728998

# %%
#b.	Are there any null values? How does this dataset need to be cleaned? 
#There are null values as shown below.
#On going through the data manually, we can see examples like China which have no values for perception of corruption for any year.
#Therefore a good strategy to clean this dataset would be to impute values with the mean of the column.
null_values = df.isnull().sum()
print("Null values in the DataFrame:")
print(null_values)
# Out:
# Null values in the DataFrame:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   20
# Social support                       13
# Healthy life expectancy at birth     54
# Freedom to make life choices         33
# Generosity                           73
# Perceptions of corruption           116
# Positive affect                      24
# Negative affect                      16
# dtype: int64

# %%
# Impute missing values with the mean of specific columns
columns_to_impute = ['Log GDP per capita', 'Social support', 'Healthy life expectancy at birth', 
                     'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 
                     'Positive affect', 'Negative affect']

imputed_df = df.fillna(df[columns_to_impute].mean())

# Check if null values are imputed
print("Null values after imputation:")
print(imputed_df.isnull().sum())
# Out:
# Null values after imputation:
# Country name                        0
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          0
# Perceptions of corruption           0
# Positive affect                     0
# Negative affect                     0
# dtype: int64

# %%
#c.	Is there any correlation between the features? 
numerical_df = imputed_df.select_dtypes(include='number')

correlation_matrix = numerical_df.corr()

# Print correlation matrix
# print("Correlation matrix:")
# print(correlation_matrix)

# %%
# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Yes. Correlations do exist in the data.
correlation_coefficient, p_value = pearsonr(numerical_df['Healthy life expectancy at birth'], numerical_df['Log GDP per capita'])

# Significance level (alpha)
alpha = 0.05

print("Correlation coefficient:", correlation_coefficient)
print("P-value:", p_value)

# Interpretation
if p_value <= alpha:
    print("There is a statistically significant correlation.")
else:
    print("There is no statistically significant correlation.")
# Out:
# Correlation coefficient: 0.8082234741167591
# P-value: 0.0
# There is a statistically significant correlation.

# %%
#d.	Are the minimum and maximum happiness scores reasonable? Are there any outliers? 

# Calculate summary statistics
min_score = numerical_df['Life Ladder'].min()
max_score = numerical_df['Life Ladder'].max()
mean_score = numerical_df['Life Ladder'].mean()
median_score = numerical_df['Life Ladder'].median()
std_score = numerical_df['Life Ladder'].std()

# Print summary statistics
print("Summary Statistics:")
print("Minimum Life Ladder score:", min_score)
print("Maximum Life Ladder score:", max_score)
print("Mean Life Ladder score:", mean_score)
print("Median Life Ladder score:", median_score)
print("Standard deviation of Life Ladder scores:", std_score)

# Visualize the distribution
plt.figure(figsize=(10, 6))
plt.hist(numerical_df['Life Ladder'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Life Ladder Scores')
plt.xlabel('Life Ladder Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Create a box plot to identify outliers
plt.figure(figsize=(8, 6))
plt.boxplot(numerical_df['Life Ladder'], vert=False)
plt.title('Boxplot of Life Ladder Scores')
plt.xlabel('Life Ladder Score')
plt.grid(True)
plt.show()
# Out:
# Summary Statistics:
# Minimum Life Ladder score: 1.2812711000442505
# Maximum Life Ladder score: 8.01893424987793
# Mean Life Ladder score: 5.479225655749149
# Median Life Ladder score: 5.432437419891357
# Standard deviation of Life Ladder scores: 1.1255293811065652

# %%
# Yes. There are a few outliers.
def find_outliers_std(df, column, threshold=2):
    mean = df[column].mean()
    std = df[column].std()
    lower_bound = mean - threshold * std
    upper_bound = mean + threshold * std
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# Find outliers in 'Life Ladder' column
outliers = find_outliers_std(numerical_df, 'Life Ladder', threshold=2)

# Print outliers
print("Outliers:")
print(len(outliers))
print(outliers)
# Out:
# Outliers:
# 44
#       year  Life Ladder  Log GDP per capita  Social support  \
# 6     2014     3.130896            7.670638        0.525568
# 9     2017     2.661718            7.647830        0.490880
# 10    2018     2.694303            7.630801        0.507516
# 11    2019     2.375092            7.640086        0.419973
# 12    2021     2.436034            7.324032        0.454175
# 13    2022     1.281271            9.389766        0.228217
# 184   2012     3.193469            7.894076        0.523027
# 291   2014     2.904535            6.722985        0.564678
# 347   2016     2.693061            6.707346        0.290184
# 442   2022     3.207197            7.006671        0.654081
# 505   2005     8.018934           10.849012        0.972372
# 506   2007     7.834233           10.888726        0.954201
# 507   2008     7.970892           10.877718        0.953912
# 509   2010     7.770515           10.836152        0.974977
# 510   2011     7.788232           10.845314        0.961736
# 632   2017     7.788252           10.769960        0.963826
# 633   2018     7.858107           10.779966        0.962155
# 634   2019     7.780348           10.791038        0.937416
# 635   2020     7.889350           10.767303        0.961621
# 636   2021     7.794378           10.794529        0.970289
# 1115  2020     2.633753            9.531043        0.546600
# 1116  2021     2.178809            9.470949        0.506775
# 1117  2022     2.352428            9.428473        0.534528
# 1126  2015     2.701591            7.365848        0.637666
# 1645  2017     3.108374            7.567849        0.516550
# 1698  2008     2.997251            7.217110        0.590737
# 1709  2022     2.560430            7.401131        0.502168
# 1794  2016     2.888112            9.389766        0.532152
# 1795  2017     2.816622            9.389766        0.556823
# 1868  2012     7.776209           11.107383        0.946864
# 1882  2012     3.164491            8.577606        0.588395
# 1883  2013     2.687553            8.418935        0.585450
# 1926  2016     2.902734            7.775247        0.637756
# 1950  2006     3.202429            7.341598        0.435414
# 1951  2008     2.807855            7.312004        0.291334
# 1952  2011     2.936221            7.405950        0.302955
# 1953  2014     2.838959            7.509245        0.444339
# 2162  2015     2.982674            7.772318        0.668683
# 2165  2018     3.057514            7.443574        0.789422
# 2181  2021     3.082155            8.082337        0.619071
# 2184  2008     3.174264            7.210233        0.843475
# 2195  2019     2.693523            7.697755        0.759162
# 2196  2020     3.159802            7.596050        0.717243
# 2197  2021     3.154578            7.656878        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 6                            52.299999                      0.508514
# 9                            53.250000                      0.427011
# 10                           53.575001                      0.373536
# 11                           53.900002                      0.393656
# 12                           54.549999                      0.394306
# 13                           54.875000                      0.368377
# 184                          53.520000                      0.768971
# 291                          53.380001                      0.431385
# 347                          44.750000                      0.624057
# 442                          55.375000                      0.664101
# 505                          68.300003                      0.971135
# 506                          68.739998                      0.932086
# 507                          68.959999                      0.969788
# 509                          69.400002                      0.943631
# 510                          69.620003                      0.934760
# 632                          70.849998                      0.962199
# 633                          70.925003                      0.937807
# 634                          71.000000                      0.947617
# 635                          71.074997                      0.962424
# 636                          71.150002                      0.963190
# 1115                         66.074997                      0.551601
# 1116                         66.150002                      0.422697
# 1117                         66.224998                      0.449575
# 1126                         52.500000                      0.671431
# 1645                         59.549999                      0.908115
# 1698                         47.040001                      0.716396
# 1709                         55.299999                      0.659596
# 1794                         53.174999                      0.439919
# 1795                         53.349998                      0.456011
# 1868                         71.519997                      0.945428
# 1882                         61.580002                      0.466771
# 1883                         59.820000                      0.454883
# 1926                         57.150002                      0.775485
# 1950                         50.240002                      0.628228
# 1951                         51.119999                      0.286814
# 1952                         52.439999                      0.584088
# 1953                         53.759998                      0.663193
# 2162                         58.400002                      0.609981
# 2165                         57.724998                      0.552726
# 2181                         55.250000                      0.832574
# 2184                         42.799999                      0.343556
# 2195                         53.099998                      0.631908
# 2196                         53.575001                      0.643303
# 2197                         54.049999                      0.667636
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 6       0.105755                   0.871242         0.491641         0.374861
# 9      -0.119410                   0.954393         0.435270         0.371326
# 10     -0.091106                   0.927606         0.384561         0.404904
# 11     -0.106016                   0.923849         0.324108         0.502474
# 12     -0.081011                   0.946299         0.178886         0.606713
# 13      0.000096                   0.733198         0.205868         0.575512
# 184    -0.111104                   0.805978         0.563015         0.230665
# 291    -0.055093                   0.807619         0.621642         0.251095
# 347     0.037318                   0.859073         0.550785         0.494268
# 442     0.085998                   0.835641         0.563382         0.461423
# 505     0.000096                   0.236522         0.776689         0.153672
# 506     0.235808                   0.206006         0.777936         0.194324
# 507     0.267880                   0.247505         0.759462         0.163091
# 509     0.238271                   0.174896         0.796209         0.154563
# 510     0.293352                   0.220043         0.777892         0.174883
# 632    -0.006553                   0.192413         0.755858         0.176066
# 633    -0.131462                   0.198605         0.748826         0.181781
# 634    -0.055773                   0.195338         0.732282         0.180733
# 635    -0.121018                   0.163636         0.747939         0.192898
# 636    -0.037467                   0.191754         0.751612         0.175449
# 1115   -0.136191                   0.883977         0.352249         0.481800
# 1116   -0.161281                   0.905279         0.263487         0.569101
# 1117   -0.125514                   0.882996         0.297508         0.429903
# 1126   -0.062922                   0.902673         0.519482         0.388489
# 1645    0.051284                   0.213757         0.724040         0.358310
# 1698    0.146608                   0.924901         0.587815         0.369601
# 1709    0.100536                   0.861837         0.493701         0.504607
# 1794    0.000096                   0.785318         0.593741         0.549257
# 1795    0.000096                   0.761270         0.564999         0.517364
# 1868    0.132033                   0.323241         0.792705         0.176007
# 1882    0.312485                   0.672964         0.451005         0.704590
# 1883    0.221555                   0.663431         0.353619         0.622230
# 1926    0.178821                   0.739247         0.649171         0.245986
# 1950   -0.026758                   0.849972         0.570732         0.348205
# 1951   -0.074570                   0.931986         0.397701         0.378715
# 1952   -0.089822                   0.832004         0.478782         0.395363
# 1953   -0.104942                   0.795342         0.536514         0.442813
# 2162   -0.135052                   0.829098         0.458002         0.321357
# 2165   -0.123616                   0.792587         0.409410         0.314870
# 2181    0.141230                   0.824031         0.655690         0.348551
# 2184   -0.073042                   0.963846         0.570538         0.250060
# 2195   -0.047464                   0.830652         0.658434         0.235354
# 2196    0.006313                   0.788523         0.660658         0.345736
# 2197   -0.075575                   0.756945         0.609917         0.241682

# %%
#e.	What is the mean happiness score? 
#The mean happiness score as calculated above
print("Mean Life Ladder score:", mean_score)
# Out:
# Mean Life Ladder score: 5.479225655749149

# %% [markdown]
# Part 3 of EDA

# %%
# Perform Kolmogorov-Smirnov test for normality on each column
def test_normality_columns(df, alpha=0.05):
    # Iterate over each numerical column in the DataFrame
    for column in df.select_dtypes(include='number'):
        # Extract data from the column
        data = df[column].dropna().values
        
        # Perform Kolmogorov-Smirnov test
        statistic, p_value = kstest(data, 'norm')
        
        # Print test results
        # print(f"Kolmogorov-Smirnov test results for column '{column}':")
        # print("Test statistic:", statistic)
        # print("P-value:", p_value)
        
        # Interpret test results
        if p_value > alpha:
            print(f"The data in column '{column}' follows a normal distribution (fail to reject H0)")
        else:
            print(f"The data in column '{column}' does not follow a normal distribution (reject H0)")

# Perform Kolmogorov-Smirnov test on each column individually
test_normality_columns(numerical_df)
# Out:
# The data in column 'year' does not follow a normal distribution (reject H0)
# The data in column 'Life Ladder' does not follow a normal distribution (reject H0)
# The data in column 'Log GDP per capita' does not follow a normal distribution (reject H0)
# The data in column 'Social support' does not follow a normal distribution (reject H0)
# The data in column 'Healthy life expectancy at birth' does not follow a normal distribution (reject H0)
# The data in column 'Freedom to make life choices' does not follow a normal distribution (reject H0)
# The data in column 'Generosity' does not follow a normal distribution (reject H0)
# The data in column 'Perceptions of corruption' does not follow a normal distribution (reject H0)
# The data in column 'Positive affect' does not follow a normal distribution (reject H0)
# The data in column 'Negative affect' does not follow a normal distribution (reject H0)

# %%
# Define a function to perform K-S test by year for all numerical columns
def kstest_by_year_all_columns(df, alpha=0.05):
    # Group the DataFrame by year
    grouped = df.groupby('year')
    
    # Get list of numerical columns
    numerical_columns = df.select_dtypes(include=['float', 'int']).columns.tolist()
    
    # Perform K-S test for each numerical column in each group
    for year, group_data in grouped:
        # print(f"Year {year}:")
        for column in numerical_columns:
            data = group_data[column].dropna().values
            statistic, p_value = kstest(data, 'norm')
            
            # Print test results
            # print(f"K-S test results for column '{column}':")
            # print("Test statistic:", statistic)
            # print("P-value:", p_value)
            
            # Interpret test results
            if p_value > alpha:
                print(f"The data for column '{column}' for year {year} follows a normal distribution (fail to reject H0)")
            # else:
            #     print(f"The data for column '{column}' for year {year} does not follow a normal distribution (reject H0)")
        # print()  # Add an empty line between years

# Perform K-S test by year for all numerical columns
kstest_by_year_all_columns(numerical_df)

# %% [markdown]
# The data is not normally distributed. Found using kstest as greater than 50 samples.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example: Print box plot along with outliers
def print_boxplot_with_outliers(df):
    # Set the style of the plots
    sns.set(style="whitegrid")
    
    # Create a box plot for each numerical column
    for column in df.select_dtypes(include=['float', 'int']):
        if(column == 'year'):
            continue
        plt.figure(figsize=(8, 6))
        
        # Create the box plot
        sns.boxplot(y=df[column], color='skyblue')
        
        # Print outliers above upper whisker
        upper_whisker = df[column].quantile(0.75) + 1.5 * (df[column].quantile(0.75) - df[column].quantile(0.25))
        outliers_above = df[df[column] > upper_whisker]
        for index, row in outliers_above.iterrows():
            print(f"Outlier above upper whisker in {column}: {row['Country name']} - {row['year']}")
        
        # Print outliers below lower whisker
        lower_whisker = df[column].quantile(0.25) - 1.5 * (df[column].quantile(0.75) - df[column].quantile(0.25))
        outliers_below = df[df[column] < lower_whisker]
        for index, row in outliers_below.iterrows():
            print(f"Outlier below lower whisker in {column}: {row['Country name']} - {row['year']}")
        
        plt.title(f'Box plot for {column}')
        plt.ylabel('Feature')
        plt.xlabel('Value')
        plt.show()

# Example usage:
# Replace 'df' with your DataFrame containing the original data
print_boxplot_with_outliers(imputed_df)
# Out:
# Outlier below lower whisker in Life Ladder: Afghanistan - 2022
# Outlier below lower whisker in Log GDP per capita: Venezuela - 2019
# Outlier below lower whisker in Social support: Afghanistan - 2008
# Outlier below lower whisker in Social support: Afghanistan - 2013
# Outlier below lower whisker in Social support: Afghanistan - 2017
# Outlier below lower whisker in Social support: Afghanistan - 2018
# Outlier below lower whisker in Social support: Afghanistan - 2019
# Outlier below lower whisker in Social support: Afghanistan - 2021
# Outlier below lower whisker in Social support: Afghanistan - 2022
# Outlier below lower whisker in Social support: Bangladesh - 2008
# Outlier below lower whisker in Social support: Bangladesh - 2021
# Outlier below lower whisker in Social support: Bangladesh - 2022
# Outlier below lower whisker in Social support: Benin - 2006
# Outlier below lower whisker in Social support: Benin - 2008
# Outlier below lower whisker in Social support: Benin - 2011
# Outlier below lower whisker in Social support: Benin - 2014
# Outlier below lower whisker in Social support: Benin - 2015
# Outlier below lower whisker in Social support: Benin - 2016
# Outlier below lower whisker in Social support: Benin - 2017
# Outlier below lower whisker in Social support: Benin - 2018
# Outlier below lower whisker in Social support: Benin - 2019
# Outlier below lower whisker in Social support: Benin - 2020
# Outlier below lower whisker in Social support: Benin - 2021
# Outlier below lower whisker in Social support: Benin - 2022
# Outlier below lower whisker in Social support: Burundi - 2008
# Outlier below lower whisker in Social support: Burundi - 2009
# Outlier below lower whisker in Social support: Burundi - 2011
# Outlier below lower whisker in Social support: Burundi - 2018
# Outlier below lower whisker in Social support: Central African Republic - 2010
# Outlier below lower whisker in Social support: Central African Republic - 2011
# Outlier below lower whisker in Social support: Central African Republic - 2016
# Outlier below lower whisker in Social support: Central African Republic - 2017
# Outlier below lower whisker in Social support: Chad - 2007
# Outlier below lower whisker in Social support: Comoros - 2022
# Outlier below lower whisker in Social support: Georgia - 2011
# Outlier below lower whisker in Social support: India - 2012
# Outlier below lower whisker in Social support: Lebanon - 2021
# Outlier below lower whisker in Social support: Malawi - 2014
# Outlier below lower whisker in Social support: Malawi - 2015
# Outlier below lower whisker in Social support: Malawi - 2022
# Outlier below lower whisker in Social support: Morocco - 2021
# Outlier below lower whisker in Social support: Pakistan - 2007
# Outlier below lower whisker in Social support: Pakistan - 2008
# Outlier below lower whisker in Social support: Pakistan - 2011
# Outlier below lower whisker in Social support: Rwanda - 2008
# Outlier below lower whisker in Social support: Rwanda - 2019
# Outlier below lower whisker in Social support: Sierra Leone - 2022
# Outlier below lower whisker in Social support: Syria - 2015
# Outlier below lower whisker in Social support: Togo - 2006
# Outlier below lower whisker in Social support: Togo - 2008
# Outlier below lower whisker in Social support: Togo - 2011
# Outlier below lower whisker in Social support: Togo - 2014
# Outlier below lower whisker in Social support: Togo - 2015
# Outlier below lower whisker in Social support: Togo - 2016
# Outlier below lower whisker in Social support: Togo - 2017
# Outlier below lower whisker in Healthy life expectancy at birth: Central African Republic - 2007
# Outlier below lower whisker in Healthy life expectancy at birth: Central African Republic - 2010
# Outlier below lower whisker in Healthy life expectancy at birth: Central African Republic - 2011
# Outlier below lower whisker in Healthy life expectancy at birth: Central African Republic - 2016
# Outlier below lower whisker in Healthy life expectancy at birth: Central African Republic - 2017
# Outlier below lower whisker in Healthy life expectancy at birth: Eswatini - 2011
# Outlier below lower whisker in Healthy life expectancy at birth: Haiti - 2006
# Outlier below lower whisker in Healthy life expectancy at birth: Haiti - 2008
# Outlier below lower whisker in Healthy life expectancy at birth: Haiti - 2010
# Outlier below lower whisker in Healthy life expectancy at birth: Haiti - 2011
# Outlier below lower whisker in Healthy life expectancy at birth: Haiti - 2012
# Outlier below lower whisker in Healthy life expectancy at birth: Haiti - 2013
# Outlier below lower whisker in Healthy life expectancy at birth: Lesotho - 2011
# Outlier below lower whisker in Healthy life expectancy at birth: Lesotho - 2016
# Outlier below lower whisker in Healthy life expectancy at birth: Lesotho - 2017
# Outlier below lower whisker in Healthy life expectancy at birth: Lesotho - 2019
# Outlier below lower whisker in Healthy life expectancy at birth: Malawi - 2006
# Outlier below lower whisker in Healthy life expectancy at birth: Mozambique - 2006
# Outlier below lower whisker in Healthy life expectancy at birth: Mozambique - 2007
# Outlier below lower whisker in Healthy life expectancy at birth: Mozambique - 2008
# Outlier below lower whisker in Healthy life expectancy at birth: South Africa - 2006
# Outlier below lower whisker in Healthy life expectancy at birth: Zimbabwe - 2006
# Outlier below lower whisker in Healthy life expectancy at birth: Zimbabwe - 2007
# Outlier below lower whisker in Healthy life expectancy at birth: Zimbabwe - 2008
# Outlier below lower whisker in Healthy life expectancy at birth: Zimbabwe - 2009
# Outlier below lower whisker in Healthy life expectancy at birth: Zimbabwe - 2010
# Outlier below lower whisker in Freedom to make life choices: Bosnia and Herzegovina - 2007
# Outlier below lower whisker in Freedom to make life choices: Bosnia and Herzegovina - 2009
# Outlier below lower whisker in Freedom to make life choices: Bosnia and Herzegovina - 2011
# Outlier below lower whisker in Freedom to make life choices: Burundi - 2008
# Outlier below lower whisker in Freedom to make life choices: Chad - 2006
# Outlier below lower whisker in Freedom to make life choices: Chad - 2007
# Outlier below lower whisker in Freedom to make life choices: Cuba - 2006
# Outlier below lower whisker in Freedom to make life choices: Haiti - 2016
# Outlier below lower whisker in Freedom to make life choices: Iraq - 2011
# Outlier below lower whisker in Freedom to make life choices: Iraq - 2012
# Outlier below lower whisker in Freedom to make life choices: Madagascar - 2008
# Outlier below lower whisker in Freedom to make life choices: Pakistan - 2008
# Outlier below lower whisker in Freedom to make life choices: State of Palestine - 2008
# Outlier below lower whisker in Freedom to make life choices: Togo - 2008
# Outlier below lower whisker in Freedom to make life choices: Zimbabwe - 2008
# Outlier above upper whisker in Generosity: Cambodia - 2011
# Outlier above upper whisker in Generosity: Gambia - 2018
# Outlier above upper whisker in Generosity: Gambia - 2019
# Outlier above upper whisker in Generosity: Indonesia - 2010
# Outlier above upper whisker in Generosity: Indonesia - 2011
# Outlier above upper whisker in Generosity: Indonesia - 2014
# Outlier above upper whisker in Generosity: Indonesia - 2015
# Outlier above upper whisker in Generosity: Indonesia - 2016
# Outlier above upper whisker in Generosity: Indonesia - 2017
# Outlier above upper whisker in Generosity: Indonesia - 2018
# Outlier above upper whisker in Generosity: Indonesia - 2019
# Outlier above upper whisker in Generosity: Indonesia - 2020
# Outlier above upper whisker in Generosity: Indonesia - 2021
# Outlier above upper whisker in Generosity: Indonesia - 2022
# Outlier above upper whisker in Generosity: Laos - 2006
# Outlier above upper whisker in Generosity: Laos - 2007
# Outlier above upper whisker in Generosity: Laos - 2008
# Outlier above upper whisker in Generosity: Laos - 2011
# Outlier above upper whisker in Generosity: Malta - 2009
# Outlier above upper whisker in Generosity: Malta - 2013
# Outlier above upper whisker in Generosity: Malta - 2014
# Outlier above upper whisker in Generosity: Myanmar - 2012
# Outlier above upper whisker in Generosity: Myanmar - 2013
# Outlier above upper whisker in Generosity: Myanmar - 2014
# Outlier above upper whisker in Generosity: Myanmar - 2015
# Outlier above upper whisker in Generosity: Myanmar - 2016
# Outlier above upper whisker in Generosity: Myanmar - 2017
# Outlier above upper whisker in Generosity: Myanmar - 2018
# Outlier above upper whisker in Generosity: Myanmar - 2019
# Outlier above upper whisker in Generosity: Myanmar - 2020
# Outlier above upper whisker in Generosity: Myanmar - 2021
# Outlier above upper whisker in Generosity: Thailand - 2007
# Outlier above upper whisker in Generosity: Thailand - 2008
# Outlier above upper whisker in Generosity: Thailand - 2009
# Outlier above upper whisker in Generosity: Thailand - 2010
# Outlier above upper whisker in Generosity: Thailand - 2011
# Outlier above upper whisker in Generosity: Thailand - 2013
# Outlier above upper whisker in Generosity: Thailand - 2014
# Outlier above upper whisker in Generosity: Ukraine - 2022
# Outlier above upper whisker in Generosity: United Kingdom - 2010
# Outlier below lower whisker in Perceptions of corruption: Australia - 2005
# Outlier below lower whisker in Perceptions of corruption: Australia - 2008
# Outlier below lower whisker in Perceptions of corruption: Australia - 2010
# Outlier below lower whisker in Perceptions of corruption: Australia - 2011
# Outlier below lower whisker in Perceptions of corruption: Australia - 2012
# Outlier below lower whisker in Perceptions of corruption: Australia - 2013
# Outlier below lower whisker in Perceptions of corruption: Australia - 2014
# Outlier below lower whisker in Perceptions of corruption: Australia - 2015
# Outlier below lower whisker in Perceptions of corruption: Australia - 2016
# Outlier below lower whisker in Perceptions of corruption: Australia - 2017
# Outlier below lower whisker in Perceptions of corruption: Australia - 2018
# Outlier below lower whisker in Perceptions of corruption: Australia - 2019
# Outlier below lower whisker in Perceptions of corruption: Bahrain - 2012
# Outlier below lower whisker in Perceptions of corruption: Canada - 2007
# Outlier below lower whisker in Perceptions of corruption: Canada - 2008
# Outlier below lower whisker in Perceptions of corruption: Canada - 2009
# Outlier below lower whisker in Perceptions of corruption: Canada - 2010
# Outlier below lower whisker in Perceptions of corruption: Canada - 2011
# Outlier below lower whisker in Perceptions of corruption: Canada - 2013
# Outlier below lower whisker in Perceptions of corruption: Canada - 2014
# Outlier below lower whisker in Perceptions of corruption: Canada - 2015
# Outlier below lower whisker in Perceptions of corruption: Canada - 2016
# Outlier below lower whisker in Perceptions of corruption: Canada - 2017
# Outlier below lower whisker in Perceptions of corruption: Canada - 2018
# Outlier below lower whisker in Perceptions of corruption: Canada - 2019
# Outlier below lower whisker in Perceptions of corruption: Canada - 2020
# Outlier below lower whisker in Perceptions of corruption: Canada - 2021
# Outlier below lower whisker in Perceptions of corruption: Canada - 2022
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2005
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2007
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2008
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2009
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2010
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2011
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2012
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2013
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2014
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2015
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2016
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2017
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2018
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2019
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2020
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2021
# Outlier below lower whisker in Perceptions of corruption: Denmark - 2022
# Outlier below lower whisker in Perceptions of corruption: Estonia - 2020
# Outlier below lower whisker in Perceptions of corruption: Estonia - 2021
# Outlier below lower whisker in Perceptions of corruption: Estonia - 2022
# Outlier below lower whisker in Perceptions of corruption: Finland - 2006
# Outlier below lower whisker in Perceptions of corruption: Finland - 2008
# Outlier below lower whisker in Perceptions of corruption: Finland - 2010
# Outlier below lower whisker in Perceptions of corruption: Finland - 2011
# Outlier below lower whisker in Perceptions of corruption: Finland - 2012
# Outlier below lower whisker in Perceptions of corruption: Finland - 2013
# Outlier below lower whisker in Perceptions of corruption: Finland - 2014
# Outlier below lower whisker in Perceptions of corruption: Finland - 2015
# Outlier below lower whisker in Perceptions of corruption: Finland - 2016
# Outlier below lower whisker in Perceptions of corruption: Finland - 2017
# Outlier below lower whisker in Perceptions of corruption: Finland - 2018
# Outlier below lower whisker in Perceptions of corruption: Finland - 2019
# Outlier below lower whisker in Perceptions of corruption: Finland - 2020
# Outlier below lower whisker in Perceptions of corruption: Finland - 2021
# Outlier below lower whisker in Perceptions of corruption: Finland - 2022
# Outlier below lower whisker in Perceptions of corruption: Georgia - 2011
# Outlier below lower whisker in Perceptions of corruption: Georgia - 2012
# Outlier below lower whisker in Perceptions of corruption: Georgia - 2013
# Outlier below lower whisker in Perceptions of corruption: Georgia - 2014
# Outlier below lower whisker in Perceptions of corruption: Germany - 2015
# Outlier below lower whisker in Perceptions of corruption: Germany - 2017
# Outlier below lower whisker in Perceptions of corruption: Germany - 2020
# Outlier below lower whisker in Perceptions of corruption: Germany - 2021
# Outlier below lower whisker in Perceptions of corruption: Germany - 2022
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2006
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2008
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2009
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2010
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2011
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2012
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2014
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2016
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2017
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2019
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2020
# Outlier below lower whisker in Perceptions of corruption: Hong Kong S.A.R. of China - 2021
# Outlier below lower whisker in Perceptions of corruption: Ireland - 2014
# Outlier below lower whisker in Perceptions of corruption: Ireland - 2015
# Outlier below lower whisker in Perceptions of corruption: Ireland - 2016
# Outlier below lower whisker in Perceptions of corruption: Ireland - 2017
# Outlier below lower whisker in Perceptions of corruption: Ireland - 2018
# Outlier below lower whisker in Perceptions of corruption: Ireland - 2019
# Outlier below lower whisker in Perceptions of corruption: Ireland - 2020
# Outlier below lower whisker in Perceptions of corruption: Ireland - 2021
# Outlier below lower whisker in Perceptions of corruption: Ireland - 2022
# Outlier below lower whisker in Perceptions of corruption: Kuwait - 2006
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2009
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2010
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2011
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2012
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2013
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2014
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2015
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2016
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2017
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2018
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2019
# Outlier below lower whisker in Perceptions of corruption: Luxembourg - 2022
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2007
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2008
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2010
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2011
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2012
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2015
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2016
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2017
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2018
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2019
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2020
# Outlier below lower whisker in Perceptions of corruption: Netherlands - 2021
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2006
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2007
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2008
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2010
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2011
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2012
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2013
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2014
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2015
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2016
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2017
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2018
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2019
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2020
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2021
# Outlier below lower whisker in Perceptions of corruption: New Zealand - 2022
# Outlier below lower whisker in Perceptions of corruption: Norway - 2006
# Outlier below lower whisker in Perceptions of corruption: Norway - 2012
# Outlier below lower whisker in Perceptions of corruption: Norway - 2014
# Outlier below lower whisker in Perceptions of corruption: Norway - 2015
# Outlier below lower whisker in Perceptions of corruption: Norway - 2016
# Outlier below lower whisker in Perceptions of corruption: Norway - 2017
# Outlier below lower whisker in Perceptions of corruption: Norway - 2018
# Outlier below lower whisker in Perceptions of corruption: Norway - 2019
# Outlier below lower whisker in Perceptions of corruption: Norway - 2020
# Outlier below lower whisker in Perceptions of corruption: Norway - 2021
# Outlier below lower whisker in Perceptions of corruption: Norway - 2022
# Outlier below lower whisker in Perceptions of corruption: Qatar - 2009
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2006
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2008
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2009
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2011
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2012
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2013
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2014
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2015
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2016
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2017
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2018
# Outlier below lower whisker in Perceptions of corruption: Rwanda - 2019
# Outlier below lower whisker in Perceptions of corruption: Saudi Arabia - 2009
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2007
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2008
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2009
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2010
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2011
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2013
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2014
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2015
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2016
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2017
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2018
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2019
# Outlier below lower whisker in Perceptions of corruption: Singapore - 2021
# Outlier below lower whisker in Perceptions of corruption: Somalia - 2015
# Outlier below lower whisker in Perceptions of corruption: Somalia - 2016
# Outlier below lower whisker in Perceptions of corruption: Somaliland region - 2011
# Outlier below lower whisker in Perceptions of corruption: Somaliland region - 2012
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2007
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2008
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2009
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2010
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2011
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2012
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2013
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2014
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2015
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2016
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2017
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2018
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2019
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2020
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2021
# Outlier below lower whisker in Perceptions of corruption: Sweden - 2022
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2006
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2009
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2012
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2014
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2015
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2016
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2017
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2018
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2019
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2020
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2021
# Outlier below lower whisker in Perceptions of corruption: Switzerland - 2022
# Outlier below lower whisker in Perceptions of corruption: United Arab Emirates - 2006
# Outlier below lower whisker in Perceptions of corruption: United Arab Emirates - 2009
# Outlier below lower whisker in Perceptions of corruption: United Arab Emirates - 2010
# Outlier below lower whisker in Perceptions of corruption: United Kingdom - 2005
# Outlier below lower whisker in Perceptions of corruption: United Kingdom - 2011
# Outlier below lower whisker in Perceptions of corruption: United Kingdom - 2012
# Outlier below lower whisker in Perceptions of corruption: United Kingdom - 2017
# Outlier below lower whisker in Perceptions of corruption: United Kingdom - 2018
# Outlier below lower whisker in Perceptions of corruption: United Kingdom - 2022
# Outlier below lower whisker in Perceptions of corruption: Uzbekistan - 2013
# Outlier below lower whisker in Positive affect: Afghanistan - 2019
# Outlier below lower whisker in Positive affect: Afghanistan - 2021
# Outlier below lower whisker in Positive affect: Afghanistan - 2022
# Outlier below lower whisker in Positive affect: Lebanon - 2019
# Outlier below lower whisker in Positive affect: Lebanon - 2021
# Outlier below lower whisker in Positive affect: Lebanon - 2022
# Outlier below lower whisker in Positive affect: Turkiye - 2021
# Outlier above upper whisker in Negative affect: Afghanistan - 2019
# Outlier above upper whisker in Negative affect: Afghanistan - 2021
# Outlier above upper whisker in Negative affect: Afghanistan - 2022
# Outlier above upper whisker in Negative affect: Armenia - 2022
# Outlier above upper whisker in Negative affect: Bahrain - 2011
# Outlier above upper whisker in Negative affect: Central African Republic - 2016
# Outlier above upper whisker in Negative affect: Central African Republic - 2017
# Outlier above upper whisker in Negative affect: Chad - 2017
# Outlier above upper whisker in Negative affect: Chad - 2018
# Outlier above upper whisker in Negative affect: Chad - 2022
# Outlier above upper whisker in Negative affect: Iran - 2012
# Outlier above upper whisker in Negative affect: Iran - 2013
# Outlier above upper whisker in Negative affect: Iran - 2014
# Outlier above upper whisker in Negative affect: Iran - 2015
# Outlier above upper whisker in Negative affect: Iran - 2016
# Outlier above upper whisker in Negative affect: Iraq - 2011
# Outlier above upper whisker in Negative affect: Iraq - 2013
# Outlier above upper whisker in Negative affect: Iraq - 2014
# Outlier above upper whisker in Negative affect: Iraq - 2015
# Outlier above upper whisker in Negative affect: Iraq - 2016
# Outlier above upper whisker in Negative affect: Iraq - 2017
# Outlier above upper whisker in Negative affect: Iraq - 2020
# Outlier above upper whisker in Negative affect: Lebanon - 2019
# Outlier above upper whisker in Negative affect: Lebanon - 2021
# Outlier above upper whisker in Negative affect: Liberia - 2016
# Outlier above upper whisker in Negative affect: Niger - 2018
# Outlier above upper whisker in Negative affect: Sierra Leone - 2017
# Outlier above upper whisker in Negative affect: Sierra Leone - 2022
# Outlier above upper whisker in Negative affect: South Sudan - 2016
# Outlier above upper whisker in Negative affect: South Sudan - 2017
# Outlier above upper whisker in Negative affect: Syria - 2011
# Outlier above upper whisker in Negative affect: Syria - 2012
# Outlier above upper whisker in Negative affect: Syria - 2013
# Outlier above upper whisker in Negative affect: Syria - 2015

# %%
items = numerical_df
corr_matrix, _ = spearmanr(items, axis=0)
mean_corr = (corr_matrix[np.tril_indices_from(corr_matrix, k=-1)]).mean()
num_items = len(items.columns)
cronbach_alpha = (mean_corr * num_items) / (1 + ((num_items - 1) * mean_corr))
print("Cronbach's Alpha:", cronbach_alpha)
# Interpret Cronbach's alpha value
if cronbach_alpha >= 0.9:
    print("Cronbach's alpha indicates excellent internal consistency.")
elif 0.8 <= cronbach_alpha < 0.9:
    print("Cronbach's alpha indicates good internal consistency.")
elif 0.7 <= cronbach_alpha < 0.8:
    print("Cronbach's alpha indicates acceptable internal consistency.")
elif 0.6 <= cronbach_alpha < 0.7:
    print("Cronbach's alpha indicates questionable internal consistency.")
else:
    print("Cronbach's alpha indicates poor internal consistency.")
# Out:
# Cronbach's Alpha: 0.6213032525004564
# Cronbach's alpha indicates questionable internal consistency.

# %%
# Assuming your data is stored in a DataFrame called 'df'
# Filter data for United States
us_data = df[df['Country name'] == 'United States']

# Split data into two groups based on presidency (Obama and Biden)
obama_data = us_data[(us_data['year'] >= 2009) & (us_data['year'] <= 2017)]
biden_data = us_data[us_data['year'] >= 2021]

min_length = min(len(obama_data), len(biden_data))

# Randomly select a subset of observations from the longer sample
random_indices = random.sample(range(len(obama_data)), min_length)
print(random_indices)
obama_data = [obama_data.iloc[i]["Life Ladder"] for i in random_indices]

random_indices = random.sample(range(len(biden_data)), min_length)
biden_data = [biden_data.iloc[i]["Life Ladder"] for i in random_indices]

# Calculate average happiness scores for each presidency
average_happiness_obama = sum(obama_data)/len(obama_data)
average_happiness_biden = sum(biden_data) / len(biden_data)

# Perform t-test
t_statistic, p_value = wilcoxon(obama_data, biden_data)

print(p_value)

# Check if the p-value is less than 0.05 (common significance level)
if p_value < 0.05:
    print("There is a significant difference in average happiness scores between Obama's and Biden's presidencies.")
else:
    print("There is no significant difference in average happiness scores between Obama's and Biden's presidencies.")

# Optionally, print the average happiness scores for comparison
print("Average happiness score during Obama's presidency:", average_happiness_obama)
print("Average happiness score during Biden's presidency:", average_happiness_biden)
# Out:
# [4, 1]
# 0.5
# There is no significant difference in average happiness scores between Obama's and Biden's presidencies.
# Average happiness score during Obama's presidency: 7.206450700759888
# Average happiness score during Biden's presidency: 6.825938940048218

# %%
df2 = pd.read_csv('HappinessAlcoholConsumption.csv')

# %%
items = df2
corr_matrix, _ = spearmanr(items, axis=0)
mean_corr = (corr_matrix[np.tril_indices_from(corr_matrix, k=-1)]).mean()
num_items = len(items.columns)
cronbach_alpha = (mean_corr * num_items) / (1 + ((num_items - 1) * mean_corr))
print("Cronbach's Alpha:", cronbach_alpha)
# Interpret Cronbach's alpha value
if cronbach_alpha >= 0.9:
    print("Cronbach's alpha indicates excellent internal consistency.")
elif 0.8 <= cronbach_alpha < 0.9:
    print("Cronbach's alpha indicates good internal consistency.")
elif 0.7 <= cronbach_alpha < 0.8:
    print("Cronbach's alpha indicates acceptable internal consistency.")
elif 0.6 <= cronbach_alpha < 0.7:
    print("Cronbach's alpha indicates questionable internal consistency.")
else:
    print("Cronbach's alpha indicates poor internal consistency.")
# Out:
# Cronbach's Alpha: 0.6186762009876985
# Cronbach's alpha indicates questionable internal consistency.

# %%
df_before_2020 = imputed_df[(imputed_df['year'] >= 2000) & (imputed_df['year'] <= 2019)]
average_life_ladder = df_before_2020.groupby('Country name')['Life Ladder'].mean().reset_index()
merged_df = pd.merge(average_life_ladder, df2, left_on='Country name', right_on='Country', how='inner')

# Select the common countries
common_countries = merged_df['Country name']

# Calculate correlation between 'Life Ladder' and 'HappinessScore'
correlation, p_value = spearmanr(merged_df['Life Ladder'], merged_df['HappinessScore'])
# correlation = merged_df['Life Ladder'].corr(merged_df['HappinessScore'])

# Print correlation coefficient
print("Correlation coefficient between Life Ladder and HappinessScore:", correlation)

# Interpretation of correlation
if correlation > 0:
    print("There is a positive correlation between Life Ladder and HappinessScore.")
elif correlation < 0:
    print("There is a negative correlation between Life Ladder and HappinessScore.")
else:
    print("There is no correlation between Life Ladder and HappinessScore.")

# Perform a statistical test (e.g., t-test, Mann-Whitney U test) if needed
# t_statistic, t_p_value = wilcoxon(merged_df['Life Ladder'], merged_df['HappinessScore'])

# # Print the test result
# print("T-test statistic:", t_statistic)
print("P-value:", p_value)

# Interpretation of the statistical test
alpha = 0.05
if p_value < alpha:
    print("There is a significant correlation between Life Ladder and HappinessScore.")
else:
    print("There is no significant correlation between Life Ladder and HappinessScore.")
# Out:
# Correlation coefficient between Life Ladder and HappinessScore: 0.9795371647165843
# There is a positive correlation between Life Ladder and HappinessScore.
# P-value: 1.6168687603416895e-80
# There is a significant correlation between Life Ladder and HappinessScore.

# %%
# imputed_df.head()
df_before_2020 = imputed_df[(imputed_df['year'] >= 2000) & (imputed_df['year'] <= 2019)]
average_life_ladder = df_before_2020.groupby('Country name')['Life Ladder'].mean().reset_index()
average_life_ladder.head()
# Out:
#   Country name  Life Ladder
# 0  Afghanistan     3.594628
# 1      Albania     4.990636
# 2      Algeria     5.389717
# 3       Angola     4.420299
# 4    Argentina     6.339423

# %%
df_before_2020 = imputed_df[(imputed_df['year'] >= 2000) & (imputed_df['year'] <= 2019)]
average_life_ladder = df_before_2020.groupby('Country name')['Perceptions of corruption'].mean().reset_index()
merged_df = pd.merge(average_life_ladder, df2, left_on='Country name', right_on='Country', how='inner')
merged_df['Alcohol_PerCapita'] = merged_df['Beer_PerCapita'] + merged_df['Spirit_PerCapita'] + merged_df['Wine_PerCapita']
# Select the common countries
common_countries = merged_df['Country name']
print(merged_df.head())

# Calculate correlation between 'Life Ladder' and 'HappinessScore'
correlation, p_value = spearmanr(merged_df['Perceptions of corruption'], merged_df['Alcohol_PerCapita'])
# correlation = merged_df['Life Ladder'].corr(merged_df['HappinessScore'])

# Print correlation coefficient
print("Correlation coefficient between Corruption and Alcohol consumption:", correlation)

# Interpretation of correlation
if correlation > 0:
    print("There is a positive correlation between Corruption and Alcohol consumption.")
elif correlation < 0:
    print("There is a negative correlation between Corruption and Alcohol consumption.")
else:
    print("There is no correlation between Corruption and Alcohol consumption.")

# Perform a statistical test (e.g., t-test, Mann-Whitney U test) if needed
# t_statistic, t_p_value = wilcoxon(merged_df['Life Ladder'], merged_df['HappinessScore'])

# # Print the test result
# print("T-test statistic:", t_statistic)
print("P-value:", p_value)

# Interpretation of the statistical test
alpha = 0.05
if p_value < alpha:
    print("There is a significant correlation between Corruption and Alcohol.")
else:
    print("There is no significant correlation between Corruption and Alcohol.")
# Out:
#   Country name  Perceptions of corruption    Country  \
# 0      Albania                   0.867527    Albania
# 1       Angola                   0.867018     Angola
# 2    Argentina                   0.843870  Argentina
# 3      Armenia                   0.846484    Armenia
# 4    Australia                   0.409601  Australia
#
#                         Region Hemisphere  HappinessScore  HDI  GDP_PerCapita  \
# 0   Central and Eastern Europe      north           4.655  782          4.132
# 1           Sub-Saharan Africa      south           3.866  577          3.309
# 2  Latin America and Caribbean      south           6.650  822         12.654
# 3   Central and Eastern Europe      north           4.360  749          3.606
# 4    Australia and New Zealand      south           7.313  938         49.897
#
#    Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita  Alcohol_PerCapita
# 0              89               132              54                275
# 1             217                57              45                319
# 2             193                25             221                439
# 3              21               179              11                211
# 4             261                72             212                545
# Correlation coefficient between Corruption and Alcohol consumption: -0.045250457676296485
# There is a negative correlation between Corruption and Alcohol consumption.
# P-value: 0.6310836957374983
# There is no significant correlation between Corruption and Alcohol.

# %%
# Assuming your data is stored in a DataFrame called 'df'
# Calculate combined alcohol consumption per capita
df2['Alcohol_PerCapita'] = df2['Beer_PerCapita'] + df2['Spirit_PerCapita'] + df2['Wine_PerCapita']

# Calculate average happiness score and average alcohol consumption per country
country_stats = df2.groupby('Country').agg({
    'HappinessScore': 'mean',
    'Alcohol_PerCapita': 'mean'
}).reset_index()

# Calculate correlation coefficient between happiness score and alcohol consumption
correlation_coefficient = country_stats['HappinessScore'].corr(country_stats['Alcohol_PerCapita'])

# Plot the relationship between alcohol consumption and happiness score
plt.figure(figsize=(8, 6))
plt.scatter(country_stats['Alcohol_PerCapita'], country_stats['HappinessScore'])
plt.title('Alcohol Consumption vs Happiness Score')
plt.xlabel('Alcohol Consumption (Per Capita)')
plt.ylabel('Happiness Score')
plt.grid(True)
plt.show()

# Print correlation coefficient
print("Correlation coefficient between alcohol consumption and happiness score:", correlation_coefficient)

# Interpret the correlation coefficient
if correlation_coefficient > 0:
    print("Countries with higher alcohol consumption tend to have higher happiness scores.")
elif correlation_coefficient < 0:
    print("Countries with higher alcohol consumption tend to have lower happiness scores.")
else:
    print("There is no significant relationship between alcohol consumption and happiness score.")
# Out:
# Correlation coefficient between alcohol consumption and happiness score: 0.5474609600344386
# Countries with higher alcohol consumption tend to have higher happiness scores.

# %%
# Divide countries into multiple groups based on alcohol consumption levels
# For demonstration purposes, let's divide them into quartiles
quartiles = country_stats['Alcohol_PerCapita'].quantile([0.25, 0.5, 0.75])
low_alcohol_countries = country_stats[country_stats['Alcohol_PerCapita'] <= quartiles[0.25]]['HappinessScore']
medium_alcohol_countries = country_stats[(country_stats['Alcohol_PerCapita'] > quartiles[0.25]) & (country_stats['Alcohol_PerCapita'] <= quartiles[0.75])]['HappinessScore']
high_alcohol_countries = country_stats[country_stats['Alcohol_PerCapita'] > quartiles[0.75]]['HappinessScore']

# %%
# Perform Kolmogorov-Smirnov test for normality
kstest_statistic, kstest_p_value = kstest(country_stats['HappinessScore'], 'norm')
print("Kolmogorov-Smirnov test for normality:")
print("Test statistic:", kstest_statistic)
print("P-value:", kstest_p_value)
if kstest_p_value < 0.05:
    print("The data is not normally distributed.")
else:
    print("The data appears to be normally distributed.")

# Perform Levene's test for homogeneity of variances
levene_test_statistic, levene_p_value = levene(low_alcohol_countries, medium_alcohol_countries, high_alcohol_countries)
print("\nLevene's test for homogeneity of variances:")
print("Test statistic:", levene_test_statistic)
print("P-value:", levene_p_value)
if levene_p_value < 0.05:
    print("The variances are not homogeneous across groups.")
else:
    print("The variances appear to be homogeneous across groups.")
# Out:
# Kolmogorov-Smirnov test for normality:
# Test statistic: 0.9989261170435373
# P-value: 0.0
# The data is not normally distributed.
#
# Levene's test for homogeneity of variances:
# Test statistic: 0.8159606481506126
# P-value: 0.4446728704829599
# The variances appear to be homogeneous across groups.

# %%
# Perform Kruskal-Wallis test
kruskal_statistic, kruskal_p_value = kruskal(low_alcohol_countries, medium_alcohol_countries, high_alcohol_countries)

# Print Kruskal-Wallis test statistic and p-value
print("Kruskal-Wallis test:")
print("Test statistic:", kruskal_statistic)
print("P-value:", kruskal_p_value)

# Interpret the results
alpha = 0.05  # significance level
if kruskal_p_value < alpha:
    print("There is a statistically significant difference in happiness scores among countries with different levels of alcohol consumption.")
else:
    print("There is no statistically significant difference in happiness scores among countries with different levels of alcohol consumption.")
# Out:
# Kruskal-Wallis test:
# Test statistic: 34.44607253907278
# P-value: 3.312305505990891e-08
# There is a statistically significant difference in happiness scores among countries with different levels of alcohol consumption.

# %%
# Perform Dunn's post-hoc test with Bonferroni correction
dunn_results = sp.posthoc_dunn([low_alcohol_countries, medium_alcohol_countries, high_alcohol_countries], p_adjust='bonferroni')

# Print pairwise comparison results
print("Pairwise comparison results:")
print(dunn_results)
# Out:
# Pairwise comparison results:
#               1         2             3
# 1  1.000000e+00  0.000005  9.468680e-08
# 2  5.248694e-06  1.000000  3.472660e-01
# 3  9.468680e-08  0.347266  1.000000e+00

# %%
# Calculate median happiness scores for each group
median_happiness_scores = [np.median(group) for group in [low_alcohol_countries, medium_alcohol_countries, high_alcohol_countries]]

# Sort groups based on median happiness scores
sorted_groups = [group for _, group in sorted(zip(median_happiness_scores, ["Low", "Medium", "High"]), reverse=True)]

# Perform Dunn's post-hoc test with Bonferroni correction
dunn_results = sp.posthoc_dunn([low_alcohol_countries, medium_alcohol_countries, high_alcohol_countries], p_adjust='bonferroni')

# Define significance level
alpha = 0.05

# Interpret pairwise comparison results
print("Ordered Groups based on Median Happiness Scores:")
print(sorted_groups)
print("\nPairwise comparison results:")
for i, group1 in enumerate(sorted_groups):
    for j, group2 in enumerate(sorted_groups):
        if i < j:
            p_value = dunn_results.iloc[i, j]
            if p_value < alpha:
                print(f"{group1} vs {group2}: Statistically significant (p-value = {p_value:.4f})")
            else:
                print(f"{group1} vs {group2}: Not statistically significant (p-value = {p_value:.4f})")
# Out:
# Ordered Groups based on Median Happiness Scores:
# ['High', 'Medium', 'Low']
#
# Pairwise comparison results:
# High vs Medium: Statistically significant (p-value = 0.0000)
# High vs Low: Statistically significant (p-value = 0.0000)
# Medium vs Low: Not statistically significant (p-value = 0.3473)

# %% [markdown]
# Therefore higher alcohol consumption tends to give more happiness except from low to medium, i.e, a high alcohol consumption actually makes the difference.

# %%
# Perform Kolmogorov-Smirnov test for normality
kstest_statistic, kstest_p_value = kstest(numerical_df['Life Ladder'], 'norm')

# Print Kolmogorov-Smirnov test statistic and p-value
print("Kolmogorov-Smirnov test for normality:")
print("Test statistic:", kstest_statistic)
print("P-value:", kstest_p_value)

# Interpret the results
alpha = 0.05  # significance level
if kstest_p_value < alpha:
    print("The data is not normally distributed.")
else:
    print("The data appears to be normally distributed.")
# Out:
# Kolmogorov-Smirnov test for normality:
# Test statistic: 0.9930491371085572
# P-value: 0.0
# The data is not normally distributed.

# %%
# Subset data into two groups: before pandemic (2017-2019) and during pandemic (2020-2021)
before_pandemic = df[df['year'].isin(range(2017, 2020))]['Life Ladder']
during_pandemic = df[df['year'].isin(range(2020, 2022))]['Life Ladder']

min_length = min(len(before_pandemic), len(during_pandemic))
# before_pandemic = before_pandemic[:min_length]
# during_pandemic = during_pandemic[:min_length]


# Randomly select a subset of observations from the longer sample
random_indices = random.sample(range(len(before_pandemic)), min_length)
print(random_indices)
before_pandemic = [before_pandemic.iloc[i] for i in random_indices]

random_indices = random.sample(range(len(during_pandemic)), min_length)
during_pandemic = [during_pandemic.iloc[i] for i in random_indices]

# Perform Mann-Whitney U test
statistic, p_value = wilcoxon(before_pandemic, during_pandemic)

print("Test statistic:", statistic)
print("P-value:", p_value)

# Interpret the results
alpha = 0.05  # significance level
if p_value < alpha:
    print("There is a significant difference in average life evaluation scores between before and during the COVID-19 pandemic.")
else:
    print("There is no significant difference in average life evaluation scores between before and during the COVID-19 pandemic.")
# Out:
# [369, 305, 228, 296, 9, 24, 37, 62, 287, 35, 212, 101, 72, 346, 403, 216, 341, 0, 38, 26, 280, 420, 292, 152, 142, 309, 245, 150, 371, 295, 266, 50, 349, 164, 284, 342, 315, 163, 223, 39, 359, 237, 299, 123, 45, 157, 149, 282, 405, 221, 132, 364, 270, 60, 57, 373, 106, 151, 215, 226, 360, 56, 399, 332, 363, 419, 171, 290, 116, 278, 261, 229, 297, 234, 46, 28, 388, 52, 190, 336, 14, 330, 3, 183, 49, 323, 372, 173, 186, 99, 34, 92, 43, 281, 48, 268, 192, 356, 279, 389, 401, 276, 256, 239, 66, 167, 386, 317, 175, 30, 94, 343, 115, 125, 59, 311, 51, 415, 104, 198, 258, 211, 230, 291, 271, 82, 408, 17, 385, 353, 19, 283, 218, 79, 181, 77, 288, 105, 117, 246, 366, 247, 262, 286, 91, 242, 370, 124, 162, 252, 205, 294, 376, 158, 201, 69, 427, 344, 208, 277, 4, 240, 410, 416, 413, 31, 298, 409, 113, 324, 128, 426, 361, 118, 138, 331, 220, 328, 166, 97, 81, 55, 307, 269, 340, 102, 398, 333, 197, 95, 8, 133, 214, 275, 312, 375, 165, 209, 148, 314, 357, 36, 303, 143, 273, 193, 316, 345, 235, 430, 156, 188, 80, 78, 11, 244, 274, 402, 195, 137, 74, 400, 207, 227, 169, 337, 18, 310, 5, 89, 355, 153, 75, 44, 293, 12, 251, 254]
# Test statistic: 11693.0
# P-value: 0.017448653966704256
# There is a significant difference in average life evaluation scores between before and during the COVID-19 pandemic.

# %%
# Perform Kruskal-Wallis test
kruskal_statistic, kruskal_p_value = kruskal(before_pandemic, during_pandemic)

# Print Kruskal-Wallis test statistic and p-value
print("Kruskal-Wallis test:")
print("Test statistic:", kruskal_statistic)
print("P-value:", kruskal_p_value)

# Interpret the results
alpha = 0.05  # significance level
if kruskal_p_value < alpha:
    print("There is a significant difference in median life evaluation scores between before and during the COVID-19 pandemic.")
else:
    print("There is no significant difference in median life evaluation scores between before and during the COVID-19 pandemic.")
# Out:
# Kruskal-Wallis test:
# Test statistic: 4.435200821333638
# P-value: 0.035205077847412135
# There is a significant difference in median life evaluation scores between before and during the COVID-19 pandemic.
