# %% [markdown]
# ## EDA

# %% [markdown]
# ## a. Which country has the highest score? Why?

# %%
import pandas as pd

data = pd.read_csv("combined.csv")
max_score = data['Life Ladder'].max()
country_with_max_score = data.loc[data['Life Ladder'] == max_score, 'Country name'].values[0]
print(f"The country with the highest Life Ladder score is {country_with_max_score} with a score of {max_score:.3f}")
# Out:
# The country with the highest Life Ladder score is Denmark with a score of 8.019

# %% [markdown]
# he highest Life Denmark score of 8.019 is held by Albania in 2019. The Life Ladder score is a measure of overall life satisfaction and well-being, considering factors like income, health, freedom, and social support. Albania's high score could be attributed to a combination of these factors being favorable in that year.

# %% [markdown]
# ## b. Are there any null values? How does this dataset need to be cleaned?

# %%
print(data.isnull().sum())
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   20
# Social support                       13
# Healthy life expectancy at birth     54
# Freedom to make life choices         33
# Generosity                           73
# Perceptions of corruption           116
# Positive affect                      24
# Negative affect                      16
# dtype: int64

# %% [markdown]
# ## c. Is there any correlation between the features?

# %%
import matplotlib.pyplot as plt
import numpy as np

# Select relevant numerical features
numeric_features = ["Life Ladder","Log GDP per capita","Social support","Healthy life expectancy at birth","Freedom to make life choices","Generosity","Perceptions of corruption","Positive affect","Negative affect"]


# Compute correlation matrix
corr = data[numeric_features].corr()

# Plot correlation heatmap with values in each cell
plt.figure(figsize=(10, 8))
plt.imshow(corr, cmap='coolwarm', interpolation='nearest', vmin=-1, vmax=1, extent=[-0.5, len(numeric_features) - 0.5, len(numeric_features) - 0.5, -0.5])

# Add annotations
for i in range(len(numeric_features)):
    for j in range(len(numeric_features)):
        plt.text(j, i, f'{corr.iloc[i, j]:.2f}', ha='center', va='center', color='white')

plt.xticks(np.arange(len(numeric_features)), numeric_features, rotation=45)
plt.yticks(np.arange(len(numeric_features)), numeric_features)
plt.title('Correlation Heatmap')

# Add color bar with specified scale
cbar = plt.colorbar(extend='both')
cbar.set_label('Correlation', rotation=270, labelpad=20)
cbar.set_ticks(np.linspace(-1, 1, 11))

plt.show()

# %% [markdown]
# ### d. Are the minimum and maximum happiness scores reasonable? Are there any outliers?

# %%
print(f"Minimum Life Ladder score: {data['Life Ladder'].min():.3f}")
print(f"Maximum Life Ladder score: {data['Life Ladder'].max():.3f}")
# Out:
# Minimum Life Ladder score: 1.281
# Maximum Life Ladder score: 8.019

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Life Ladder')
plt.title('Box Plot of Life Ladder Scores')
plt.show()

# %% [markdown]
# ### e. What is the mean happiness score?

# %%
mean_score = data['Life Ladder'].mean()
print(f"The mean Life Ladder score is {mean_score:.3f}")
# Out:
# The mean Life Ladder score is 5.479
